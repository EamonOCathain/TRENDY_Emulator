# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# %%
path_yearly = "/Net/Groups/BSI/work_scratch/ecathain/mpi2/TRENDY/Raw/OUTPUT/JSBACH/S0/JSBACH_S0_nbp.nc"
path_monthly = "/Net/Groups/BSI/work_scratch/ecathain/mpi2/TRENDY/Raw/OUTPUT/JSBACH/S0/JSBACH_S0_gpp.nc"

# %%
arr_yearly, dt_yearly= Time.full_extract(path_yearly)
arr_monthly, dt_monthly = Time.full_extract(path_monthly)

# %%
combined_yearly = np.rec.fromarrays([dt_yearly, arr_yearly], names='time,values')
combined_monthly = np.rec.fromarrays([dt_monthly, arr_monthly], names='time,values')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

# Plot first dataset
plt.plot(combined_yearly.time, combined_yearly.values, label="Dataset 1", marker='o')

# Plot second dataset
plt.plot(combined_monthly.time, combined_monthly.values, label="Dataset 2", marker='s')

# Labels and legend
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Combined Time Series Plot")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
